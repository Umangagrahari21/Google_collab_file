# %% [markdown]
# <a href="https://colab.research.google.com/github/Umangagrahari21/Google_collab_file/blob/main/GenAI_Day03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Background: An online job search platform allows users to search for job listings using free-text queries. The platform
# stores thousands of job descriptions and user queries in English. However, the search engine often fails to retum
# relevant results because different grammatical forms of the same word are treated as separate terms. For example, job
# descriptions may contain words like "developing", "developer", and "development, while users may  search for 'develop'.
# This matches reduces the accuracy of search results. To improve search relevance and reduce vocabulary size, the
# platform plans to apply platform plans
#
# Problem Statement
# You are part of a data science team responsible for enhancing the search functionality of the job portal. Your task is
# to analyze how stemming can help normalize textualdata and compare the behavior of different stemming techniques.
# Consider a dataset containing. a) Job descriptions b) User search queries before applying any machine leaming or
# information retrieval techniques, the text must be preprocessed using stemming algirithms.

# %%
from nltk.stem import PorterStemmer,LancasterStemmer,SnowballStemmer



word=["deveop","developing","developer","development","analysis","analyst","analytics","happily"]

port=PorterStemmer()
lan=LancasterStemmer()
snow=SnowballStemmer("english")

print("word".ljust(15),"proter".ljust(12),"lancaster".ljust(12),"snowball")
print("-"*55)

for i in word:
  print(i.ljust(15),
        port.stem(i).ljust(12),
        lan.stem(i).ljust(12),
        snow.stem(i))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2619140219.py in <cell line: 0>()
#       3 from nltk.tokenize import word_tokenize
#       4 import string
# ----> 5 nltk.download('punkt')
#       6
#       7 word=["deveop","developing","developer","development","analysis","analyst","analytics","happily"]
#
# /usr/local/lib/python3.12/dist-packages/nltk/downloader.py in download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to)
#     772                 )
#     773
# --> 774             for msg in self.incr_download(info_or_id, download_dir, force):
#     775                 # Error messages
#     776                 if isinstance(msg, ErrorMessage):
#
# /usr/local/lib/python3.12/dist-packages/nltk/downloader.py in incr_download(self, info_or_id, download_dir, force)
# ...

# %%
import nltk
from nltk.stem import PorterStemmer, SnowballStemmer
from nltk.tokenize import word_tokenize
import string
nltk.download('punkt')

# pip install --upgrade nltk




# job_decriptions=[
#     "We are developing scalable software systems",
"Looking for experienced dvelopers",
"software development and testing roles available"
# ]

# user_queries=[
#     "develop","software developer",
#     "testing jobs"
# ]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1927560345.py in <cell line: 0>()
#       3 from nltk.tokenize import word_tokenize
#       4 import string
# ----> 5 nltk.download('punkt')
#       6
#       7 # pip install --upgrade nltk
#
# /usr/local/lib/python3.12/dist-packages/nltk/downloader.py in download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to)
#     772                 )
#     773
# --> 774             for msg in self.incr_download(info_or_id, download_dir, force):
#     775                 # Error messages
#     776                 if isinstance(msg, ErrorMessage):
#
# /usr/local/lib/python3.12/dist-packages/nltk/downloader.py in incr_download(self, info_or_id, download_dir, force)
#     627         # Look up the requested collection or package.
#     628         try:
# ...
